# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\DELL\Downloads\archive (2)\placementdata.csv")

# %%
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %% [markdown]
# <h1>Inspection</h1>

# %%
# first 5 rows of data
df.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# ...

# %%
# first 25 rows
df.head(25)
# Out:
#     StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0           1   7.5            1         1                         1
# 1           2   8.9            0         3                         2
# 2           3   7.3            1         2                         2
# 3           4   7.5            1         1                         2
# 4           5   8.3            1         2                         2
# 5           6   7.0            0         2                         2
# 6           7   7.7            1         1                         1
# 7           8   7.7            2         1                         0
# 8           9   6.5            1         1                         0
# 9          10   7.8            1         3                         2
# 10         11   8.3            2         3                         2
# 11         12   7.9            1         3                         2
# 12         13   8.3            2         3                         2
# ...

# %%
# last 5 rows
df.tail()
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 9995                 72               3.9                       Yes
# 9996                 90               4.8                        No
# 9997                 70               4.8                       Yes
# 9998                 87               4.8                       Yes
# 9999                 66               3.8                        No
#
#      PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 9995                No         85         66       NotPlaced
# ...

# %%
# last 45 rows
df.tail(45)
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 9955       9956   8.1            2         1                         0
# 9956       9957   8.0            1         3                         1
# 9957       9958   7.5            1         1                         0
# 9958       9959   8.2            2         3                         2
# 9959       9960   7.7            0         1                         1
# 9960       9961   8.3            1         1                         0
# 9961       9962   6.9            1         3                         0
# 9962       9963   7.3            1         1                         0
# 9963       9964   6.5            2         1                         0
# 9964       9965   7.5            1         3                         1
# 9965       9966   6.8            0         2                         1
# 9966       9967   8.3            1         3                         2
# ...

# %%
# randomly selects 1 rows
df.sample()
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 1783       1784   8.6            2         3                         2
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 1783                 90               4.6                       Yes
#
#      PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 1783               Yes         69         86       NotPlaced

# %%
# gives statistical summary of df
df.describe()
# Out:
#          StudentID          CGPA   Internships      Projects  \
# count  10000.00000  10000.000000  10000.000000  10000.000000
# mean    5000.50000      7.698010      1.049200      2.026600
# std     2886.89568      0.640131      0.665901      0.867968
# min        1.00000      6.500000      0.000000      0.000000
# 25%     2500.75000      7.400000      1.000000      1.000000
# 50%     5000.50000      7.700000      1.000000      2.000000
# 75%     7500.25000      8.200000      1.000000      3.000000
# max    10000.00000      9.100000      2.000000      3.000000
#
#        Workshops/Certifications  AptitudeTestScore  SoftSkillsRating  \
# count              10000.000000       10000.000000      10000.000000
# mean                   1.013200          79.449900          4.323960
# std                    0.904272           8.159997          0.411622
# min                    0.000000          60.000000          3.000000
# ...

# %%
# information about df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
# returns columns
df.columns
# Out:
# Index(['StudentID', 'CGPA', 'Internships', 'Projects',
#        'Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating',
#        'ExtracurricularActivities', 'PlacementTraining', 'SSC_Marks',
#        'HSC_Marks', 'PlacementStatus'],
#       dtype='object')

# %%
# datatypes of all columns
df.dtypes
# Out:
# StudentID                      int64
# CGPA                         float64
# Internships                    int64
# Projects                       int64
# Workshops/Certifications       int64
# AptitudeTestScore              int64
# SoftSkillsRating             float64
# ExtracurricularActivities     object
# PlacementTraining             object
# SSC_Marks                      int64
# HSC_Marks                      int64
# PlacementStatus               object
# dtype: object

# %%
# shape of df
df.shape
# Out:
# (10000, 12)

# %%
# reteriving single col
df['Projects']
# Out:
# 0       1
# 1       3
# 2       2
# 3       1
# 4       2
#        ..
# 9995    1
# 9996    1
# 9997    3
# 9998    3
# 9999    1
# Name: Projects, Length: 10000, dtype: int64

# %%
df['PlacementStatus']
# Out:
# 0       NotPlaced
# 1          Placed
# 2       NotPlaced
# 3          Placed
# 4          Placed
#           ...
# 9995    NotPlaced
# 9996       Placed
# 9997       Placed
# 9998       Placed
# 9999    NotPlaced
# Name: PlacementStatus, Length: 10000, dtype: object

# %%
df['PlacementTraining']
# Out:
# 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 9995     No
# 9996     No
# 9997    Yes
# 9998    Yes
# 9999     No
# Name: PlacementTraining, Length: 10000, dtype: object

# %%
# multiple column from df
df[['StudentID','CGPA','SSC_Marks','HSC_Marks']]
# Out:
#       StudentID  CGPA  SSC_Marks  HSC_Marks
# 0             1   7.5         61         79
# 1             2   8.9         78         82
# 2             3   7.3         79         80
# 3             4   7.5         81         80
# 4             5   8.3         74         88
# ...         ...   ...        ...        ...
# 9995       9996   7.5         85         66
# 9996       9997   7.4         84         67
# 9997       9998   8.4         79         81
# 9998       9999   8.9         71         85
# 9999      10000   8.4         62         66
#
# [10000 rows x 4 columns]

# %%
# unique values
df['StudentID'].unique()
# Out:
# array([    1,     2,     3, ...,  9998,  9999, 10000], dtype=int64)

# %%
df['CGPA'].unique()
# Out:
# array([7.5, 8.9, 7.3, 8.3, 7. , 7.7, 6.5, 7.8, 7.9, 7.4, 8.6, 8.2, 6.8,
#        7.6, 6.7, 8.4, 8.5, 6.9, 8.1, 8.8, 8. , 6.6, 7.2, 7.1, 8.7, 9. ,
#        9.1])

# %%
df['Internships'].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
df['Projects'].unique()
# Out:
# array([1, 3, 2, 0], dtype=int64)

# %%
df['Workshops/Certifications'].unique()
# Out:
# array([1, 2, 0, 3], dtype=int64)

# %%
df['AptitudeTestScore'].unique()
# Out:
# array([65, 90, 82, 85, 86, 71, 76, 84, 79, 74, 66, 78, 73, 70, 72, 77, 60,
#        81, 63, 75, 67, 89, 88, 62, 80, 68, 87, 69, 83, 64, 61],
#       dtype=int64)

# %%
df['SoftSkillsRating'].unique()
# Out:
# array([4.4, 4. , 4.8, 4.5, 4.2, 3.5, 3.9, 4.6, 4.1, 4.7, 3.4, 3.8, 4.3,
#        3.6, 3.3, 3.2, 3.7, 3. , 3.1])

# %%
df['ExtracurricularActivities'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['PlacementTraining'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# taking unique values of all col
col=df.columns
for i in col:
    print("column:",i)
    print("unique values")
    print(df[i].unique())
    print("------------------")
# Out:
# column: StudentID
# unique values
# [    1     2     3 ...  9998  9999 10000]
# ------------------
# column: CGPA
# unique values
# [7.5 8.9 7.3 8.3 7.  7.7 6.5 7.8 7.9 7.4 8.6 8.2 6.8 7.6 6.7 8.4 8.5 6.9
#  8.1 8.8 8.  6.6 7.2 7.1 8.7 9.  9.1]
# ------------------
# column: Internships
# unique values
# [1 0 2]
# ------------------
# column: Projects
# unique values
# [1 3 2 0]
# ------------------
# column: Workshops/Certifications
# unique values
# [1 2 0 3]
# ------------------
# column: AptitudeTestScore
# unique values
# [65 90 82 85 86 71 76 84 79 74 66 78 73 70 72 77 60 81 63 75 67 89 88 62
#  80 68 87 69 83 64 61]
# ------------------
# column: SoftSkillsRating
# unique values
# [4.4 4.  4.8 4.5 4.2 3.5 3.9 4.6 4.1 4.7 3.4 3.8 4.3 3.6 3.3 3.2 3.7 3.
#  3.1]
# ------------------
# column: ExtracurricularActivities
# unique values
# ['No' 'Yes']
# ------------------
# column: PlacementTraining
# unique values
# ['No' 'Yes']
# ------------------
# column: SSC_Marks
# ...

# %%
# value_counts
df['PlacementStatus'].value_counts()
# Out:
# NotPlaced    5803
# Placed       4197
# Name: PlacementStatus, dtype: int64

# %%
# displays all value_counts
col=df.columns
for i in col:
    print("column:",i)
    print("value counts foe column",i)
    print(df[i].value_counts())
    print("------------------")
# Out:
# column: StudentID
# value counts foe column StudentID
# 1        1
# 6671     1
# 6664     1
# 6665     1
# 6666     1
#         ..
# 3334     1
# 3335     1
# 3336     1
# 3337     1
# 10000    1
# Name: StudentID, Length: 10000, dtype: int64
# ------------------
# column: CGPA
# value counts foe column CGPA
# 6.5    833
# 7.6    814
# 7.5    798
# 8.3    662
# 8.2    655
# 7.7    622
# 8.4    608
# 7.4    590
# 8.1    534
# 7.8    453
# 8.0    445
# 8.5    428
# 7.9    384
# 8.6    309
# 6.6    278
# 7.3    267
# 6.7    265
# 6.8    212
# 8.7    187
# 6.9    165
# 7.2    127
# 7.0    121
# 7.1     92
# 8.8     86
# 8.9     49
# 9.0     13
# 9.1      3
# Name: CGPA, dtype: int64
# ------------------
# column: Internships
# value counts foe column Internships
# 1    5542
# 2    2475
# 0    1983
# Name: Internships, dtype: int64
# ------------------
# column: Projects
# value counts foe column Projects
# 3    3873
# 1    3547
# 2    2550
# 0      30
# Name: Projects, dtype: int64
# ...

# %%
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
# reterive students who is having more than 8 cgpa
df[df['CGPA']>8]
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 1             2   8.9            0         3                         2
# 4             5   8.3            1         2                         2
# 10           11   8.3            2         3                         2
# 12           13   8.3            2         3                         2
# 16           17   8.6            0         3                         0
# ...         ...   ...          ...       ...                       ...
# 9989       9990   8.3            2         3                         0
# 9991       9992   8.4            2         3                         1
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
# list the students who had attended less than 2 internships
df[df['Internships']<2]
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
# reterive students who r having extra curricular activities
df[df['ExtracurricularActivities']=='Yes']
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# 5             6   7.0            0         2                         2
# ...         ...   ...          ...       ...                       ...
# 9992       9993   8.0            2         1                         2
# 9994       9995   7.8            2         2                         2
# 9995       9996   7.5            1         1                         2
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
# reterive studentid,projects,SSC_Marks,HSC_Marks students who r placed 
df[df['PlacementStatus']=='Placed'][['StudentID','Projects','SSC_Marks','HSC_Marks']]
# Out:
#       StudentID  Projects  SSC_Marks  HSC_Marks
# 1             2         3         78         82
# 3             4         1         81         80
# 4             5         2         74         88
# 9            10         3         85         86
# 10           11         3         82         88
# ...         ...       ...        ...        ...
# 9991       9992         3         84         87
# 9992       9993         1         75         72
# 9996       9997         1         84         67
# 9997       9998         3         79         81
# 9998       9999         3         71         85
#
# [4197 rows x 4 columns]

# %% [markdown]
# <h1>Filtering Conditions</h1>

# %%
# not having Extracurricular Activities and having Placement Training
df[(df['ExtracurricularActivities']=='No')&(df['PlacementTraining']=='Yes')]
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 8             9   6.5            1         1                         0
# 13           14   7.7            1         1                         1
# 19           20   7.4            1         2                         0
# 20           21   7.6            2         1                         0
# 21           22   7.4            1         2                         1
# ...         ...   ...          ...       ...                       ...
# 9981       9982   7.8            1         1                         0
# 9986       9987   7.5            0         2                         1
# 9988       9989   7.3            1         2                         1
# 9990       9991   7.4            0         3                         1
# 9993       9994   6.6            1         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
# cgpa less than 7 and certification less than equal to 2
df[(df['CGPA']<7)&(df['Workshops/Certifications']<=2)]
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 8             9   6.5            1         1                         0
# 18           19   6.8            2         3                         0
# 25           26   6.7            1         1                         1
# 34           35   6.9            0         1                         0
# 39           40   6.7            0         3                         2
# ...         ...   ...          ...       ...                       ...
# 9961       9962   6.9            1         3                         0
# 9963       9964   6.5            2         1                         0
# 9965       9966   6.8            0         2                         1
# 9983       9984   6.6            2         1                         0
# 9993       9994   6.6            1         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
# SSC_Marks less than 60 or HSC_Marks less than 80
df[(df['SSC_Marks']<60)|(df['HSC_Marks']<80)]
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 5             6   7.0            0         2                         2
# 6             7   7.7            1         1                         1
# 7             8   7.7            2         1                         0
# 8             9   6.5            1         1                         0
# ...         ...   ...          ...       ...                       ...
# 9993       9994   6.6            1         1                         1
# 9994       9995   7.8            2         2                         2
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
# cgpa less than 8 or who r not placed
df[(df['CGPA']<8)|(df['PlacementStatus']=='NotPlaced')]
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 5             6   7.0            0         2                         2
# 6             7   7.7            1         1                         1
# ...         ...   ...          ...       ...                       ...
# 9993       9994   6.6            1         1                         1
# 9994       9995   7.8            2         2                         2
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %% [markdown]
# <h1>preprocessing</h1>

# %%
# checking null values
df.isna().sum()
# Out:
# StudentID                    0
# CGPA                         0
# Internships                  0
# Projects                     0
# Workshops/Certifications     0
# AptitudeTestScore            0
# SoftSkillsRating             0
# ExtracurricularActivities    0
# PlacementTraining            0
# SSC_Marks                    0
# HSC_Marks                    0
# PlacementStatus              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %% [markdown]
# <h1>Visualization</h1>

# %%
# scatter plot
import matplotlib.pyplot as plt

# cgpa lss than 7 and Workshops/Certifications more than 2, their SSLC marks
bmi_df=df[(df['CGPA']<=7)&(df['Workshops/Certifications']>2)][['CGPA','SSC_Marks']]
x=bmi_df['CGPA']
y=bmi_df['SSC_Marks']
plt.figure(figsize=(8,6),dpi=100)
plt.plot(x,y)
plt.title("CGPA vs SSC_Marks")
plt.xlabel("CGPA of Students")
plt.ylabel("SSC_Marks")
plt.show()

# %%
# age 70-100 who is having stroke visualization their avg glocose level using scatter plt
import matplotlib.pyplot as plt

avg_plt=df[(df['CGPA']>8)&(df['Workshops/Certifications']>1)][['CGPA','HSC_Marks']]
x=avg_plt['CGPA']
y=avg_plt['HSC_Marks']
plt.xlabel("CGPA",fontdict={"family":"algerian","color":"red","size":20})
plt.ylabel("HSC_Marks",fontdict={"family":"arial","color":"red","size":20})
plt.title("CGPA vs HSC_Marks",fontdict={"family":"serif","color":"blue","size":20})
plt.scatter(x,y,color="purple")
plt.show()

# %%
# bar graph
# visualization PlacementStatus not having PlacementTraining
placement_series=df[df['PlacementTraining']=='No']['PlacementStatus']
placement_bar=placement_series.value_counts()
type(placement_bar)
x=placement_bar.index
y=placement_bar.values



plt.figure(figsize=(8,6),dpi=100)
plt.bar(x,y,color="orange")
plt.title("placement status of a Student")
plt.xlabel("Placement status")
plt.ylabel("counts")
plt.show()

# %%
# visualization PlacementStatus having PlacementTraining
placement_series=df[df['PlacementTraining']=='Yes']['PlacementStatus']
placement_bar=placement_series.value_counts()
type(placement_bar)
x=placement_bar.index
y=placement_bar.values



plt.figure(figsize=(8,6),dpi=100)
plt.bar(x,y,color="red")
plt.title("placement status of a Student")
plt.xlabel("Placement status")
plt.ylabel("counts")
plt.show()

# %%
# histogram
plt.figure(figsize=(8,6),dpi=100)
x=df['CGPA']
plt.hist(x,bins=[6,7,8,9],color="purple")
plt.title("Distribution of CGPA")
plt.xlabel("CGPA")
plt.ylabel("counts")
plt.xticks([6,7,8,9])
plt.show()

# %%
# pie graph
pla=df['PlacementStatus'].value_counts()
print(type(pla))
print(pla)
x=pla.values
lb=pla.index
plt.figure(figsize=(8,6),dpi=100)
plt.pie(x,labels=lb,colors=["yellow","red"])
plt.legend(lb)
plt.title("Placement distribution")
plt.show()
# Out:
# <class 'pandas.core.series.Series'>
# NotPlaced    5803
# Placed       4197
# Name: PlacementStatus, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
# label encoding

# step 1:importing
from sklearn.preprocessing import LabelEncoder

# step 2:create object for class
lb_act=LabelEncoder()

# step 3:pass the data to transform
df['ExtracurricularActivities']=lb_act.fit_transform(df['ExtracurricularActivities'])
df['ExtracurricularActivities']
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    1
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: ExtracurricularActivities, Length: 10000, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  int32
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int32(1), int64(7), object(2)
# memory usage: 898.6+ KB

# %%
# step 1:importing
from sklearn.preprocessing import LabelEncoder
df['PlacementTraining'] = df['PlacementTraining'].str.lower()  # Convert all values to lowercase

lb1_tra = LabelEncoder()
lb1_tra.fit(["no", "yes"])  # Fit on lowercase labels

df['PlacementTraining'] = lb1_tra.transform(df['PlacementTraining'])  # Now this should work

print(df['PlacementTraining'].unique())
# Out:
# [0 1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  int32
#  8   PlacementTraining          10000 non-null  int32
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int32(2), int64(7), object(1)
# memory usage: 859.5+ KB

# %%
# label encoding

# step 1:importing
from sklearn.preprocessing import LabelEncoder

# step 2:create object for class
lb2_sta=LabelEncoder()


df['PlacementStatus']=lb2_sta.fit_transform(df['PlacementStatus'])
df['PlacementStatus']
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    1
# 9997    1
# 9998    1
# 9999    0
# Name: PlacementStatus, Length: 10000, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  int32
#  8   PlacementTraining          10000 non-null  int32
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  int32
# dtypes: float64(2), int32(3), int64(7)
# memory usage: 820.4 KB

# %%
df.drop(['StudentID'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CGPA                       10000 non-null  float64
#  1   Internships                10000 non-null  int64
#  2   Projects                   10000 non-null  int64
#  3   Workshops/Certifications   10000 non-null  int64
#  4   AptitudeTestScore          10000 non-null  int64
#  5   SoftSkillsRating           10000 non-null  float64
#  6   ExtracurricularActivities  10000 non-null  int32
#  7   PlacementTraining          10000 non-null  int32
#  8   SSC_Marks                  10000 non-null  int64
#  9   HSC_Marks                  10000 non-null  int64
#  10  PlacementStatus            10000 non-null  int32
# dtypes: float64(2), int32(3), int64(6)
# memory usage: 742.3 KB

# %% [markdown]
# <h1>labeling the data</h1>

# %%
x=df.drop('PlacementStatus',axis=1)
y=df['PlacementStatus']

# %%
x.shape
# Out:
# (10000, 10)

# %%
y.shape
# Out:
# (10000,)

# %% [markdown]
# <h1>MODEL BUILDING , TRAINING,TESTING AND EVALUATION<h1>

# %%
y.unique()
y.value_counts()
# Out:
# 0    5803
# 1    4197
# Name: PlacementStatus, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=42)

# %%
x_train.shape
# Out:
# (8000, 10)

# %%
x_train.shape
# Out:
# (8000, 10)

# %%
y_train.value_counts()
# Out:
# 0    4642
# 1    3358
# Name: PlacementStatus, dtype: int64

# %% [markdown]
# <h1>splitting the data</h1>

# %%
from imblearn.over_sampling import SMOTE

smt = SMOTE()
x_train_sampled, y_train_sampled = smt.fit_resample(x_train, y_train)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %%
x_train_sampled.shape
# Out:
# (9284, 10)

# %%
y_train_sampled.shape
# Out:
# (9284,)

# %%
x_test.shape
# Out:
# (2000, 10)

# %%
y_test.shape
# Out:
# (2000,)

# %%
# logistic regression
# model building
# step 1.importing algorithm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns


# object creation
# model name is same as a object name-lr
lr=LogisticRegression()
lr.fit(x_train_sampled,y_train_sampled)
result=lr.predict(x_test)
result

# model evalution
lr_acc=accuracy_score(y_test,result)
print("accurcay score for lr model",lr_acc)
lr_cm=confusion_matrix(y_test,result)
plt.figure(figsize=(8,6),dpi=100)
plt.title("LR CONFUSION MATRIX")
sns.heatmap(lr_cm,annot=True,fmt='d')
plt.xlabel("predicted value")
plt.ylabel("actual value")
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# accurcay score for lr model 0.762

# %%
# decision tree classifier
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# model training
dt.fit(x_train_sampled, y_train_sampled)
dt_result=dt.predict(x_test)
dt_result

# model evalution
dt_acc=accuracy_score(y_test,dt_result)
print("accurcay score for dt model",dt_acc)
dt_cm=confusion_matrix(y_test,dt_result)
plt.figure(figsize=(8,6),dpi=100)
plt.title("DF CONFUSION MATRIX")
sns.heatmap(dt_cm,annot=True,fmt='d')
plt.xlabel("predicted value")
plt.ylabel("actual value")
plt.show()
# Out:
# accurcay score for dt model 0.6995

# %%
# Super vector classifier
from sklearn.svm import SVC
sc=SVC()


# model training
sc.fit(x_train_sampled, y_train_sampled)

# model testing
sc_result=sc.predict(x_test)
sc_result


# model evalution
sc_acc=accuracy_score(y_test,sc_result)
print("accurcay score for sc model",sc_acc)
sc_cm=confusion_matrix(y_test,sc_result)
plt.figure(figsize=(8,6),dpi=100)
plt.title("SVC CONFUSION MATRIX")
sns.heatmap(sc_cm,annot=True,fmt='d')
plt.xlabel("predicted value")
plt.ylabel("actual value")
plt.show()
# Out:
# accurcay score for sc model 0.791

# %%
# random forest classifier
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# model training
rf.fit(x_train_sampled, y_train_sampled)

# model testing
rf_result=rf.predict(x_test)
rf_result


# model evalution
rf_acc=accuracy_score(y_test,rf_result)
print("accurcay score for rf model",rf_acc)
rf_cm=confusion_matrix(y_test,rf_result)
plt.figure(figsize=(8,6),dpi=100)
plt.title("RF CONFUSION MATRIX")
sns.heatmap(rf_cm,annot=True,fmt='d')
plt.xlabel("predicted value")
plt.ylabel("actual value")
plt.show()
# Out:
# accurcay score for rf model 0.783

# %%
df
# Out:
#       CGPA  Internships  Projects  Workshops/Certifications  \
# 0      7.5            1         1                         1
# 1      8.9            0         3                         2
# 2      7.3            1         2                         2
# 3      7.5            1         1                         2
# 4      8.3            1         2                         2
# ...    ...          ...       ...                       ...
# 9995   7.5            1         1                         2
# 9996   7.4            0         1                         0
# 9997   8.4            1         3                         0
# 9998   8.9            0         3                         2
# 9999   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating  ExtracurricularActivities  \
# 0                    65               4.4                          0
# 1                    90               4.0                          1
# ...

# %% [markdown]
# <h1>Deployment</h1>

# %%
# deployment
x_test.iloc[100].values
# Out:
# array([ 7.5,  1. ,  3. ,  1. , 72. ,  4.2,  1. ,  0. , 90. , 80. ])

# %%
y_test.iloc[100]
# Out:
# 0

# %%
# how to predict
result=sc.predict([[7.5,  1. ,  3. ,  0. , 80. ,  4. ,  1. ,  1. , 60. , 62.]])
print(result)
# Out:
# [0]
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
# model deployment
# step 1:saving all models

# %%
import pickle

# %%
with open("place-rf-model.pkl","wb")as file:
    pickle.dump(rf,file)

# %%
with open("lb-activities.pkl","wb")as file:
    pickle.dump(lb_act,file)

# %%
with open("lb1-training.pkl","wb")as file:
    pickle.dump(lb1_tra,file)

# %%
with open("lb2-status.pkl","wb")as file:
    pickle.dump(lb2_sta,file)

# %%
# step 2:loading the saved model
with open("place-rf-model.pkl","rb")as file:
    place_model=pickle.load(file)

# %%
with open("lb-activities.pkl","rb")as file:
    lb_act=pickle.load(file)

# %%
with open("lb1-training.pkl","rb")as file:
    lb1_tra=pickle.load(file)

# %%
with open("lb2-status.pkl","rb")as file:
    lb2_sta=pickle.load(file)

# %%
x_train_sampled.columns
# Out:
# Index(['CGPA', 'Internships', 'Projects', 'Workshops/Certifications',
#        'AptitudeTestScore', 'SoftSkillsRating', 'ExtracurricularActivities',
#        'PlacementTraining', 'SSC_Marks', 'HSC_Marks'],
#       dtype='object')

# %%
def predict_placement(cgpa=8.0, Internships=1, Projects=2, Workshopscertifications=1,
                      AptitudeTestScore=70, SoftSkillsRating=7, ExtracurricularActivities="yes",
                      PlacementTraining="yes", SSC_Marks=85, HSC_Marks=80):

    lst = []

    # Add numeric features
    lst.append(float(cgpa))
    lst.append(int(Internships))
    lst.append(int(Projects))
    lst.append(int(Workshopscertifications))
    lst.append(float(AptitudeTestScore))
    lst.append(int(SoftSkillsRating))
    lst.append(float(SSC_Marks))
    lst.append(float(HSC_Marks))

    PlacementTraining = str(PlacementTraining).strip().lower()
    if PlacementTraining not in lb1_tra.classes_:
        return "Error: Invalid value for Placement Training"
    placement_training_encoded = lb1_tra.transform([PlacementTraining])

    ExtracurricularActivities = str(ExtracurricularActivities).strip().capitalize()
    if ExtracurricularActivities not in lb_act.classes_:
        return "Error: Invalid value for Extracurricular Activities"
    extracurricular_encoded = lb_act.transform([ExtracurricularActivities])
    
    
    lst += list(placement_training_encoded)
    lst += list(extracurricular_encoded)

    # Predict
    result = place_model.predict([lst])
    print("Raw model output:", result)

    return "Student is likely to be placed" if result[0] == 1 else "Student is unlikely to be placed"

# %%
predict_placement()
# Out:
# Raw model output: [0]
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 'Student is unlikely to be placed'

# %%
CGPA = float(input("Enter CGPA: "))
Internships = int(input("Enter number of internships: "))
Projects = int(input("Enter number of projects: "))
Certifications = int(input("Enter number of certifications/workshops: "))
Aptitude = float(input("Enter Aptitude Test Score: "))
SoftSkills = float(input("Enter Soft Skills Rating: "))
Extracurricular =(input("Participated in extracurricular activities?(yes/no): "))
Training =(input("Attended placement training?(yes/no): "))
SSC = float(input("Enter SSC marks: "))
HSC = float(input("Enter HSC marks: "))

# Prediction
result = predict_placement(CGPA, Internships, Projects, Certifications, Aptitude, SoftSkills,Extracurricular, Training, SSC, HSC)
print("Model prediction result:", result)
# Out:
# Enter CGPA: 4
# Enter number of internships: 0
# Enter number of projects: 1
# Enter number of certifications/workshops: 1
# Enter Aptitude Test Score: 45
# Enter Soft Skills Rating: 4
# Participated in extracurricular activities?(yes/no): no
# Attended placement training?(yes/no): no
# Enter SSC marks: 45
# Enter HSC marks: 35
# Raw model output: [0]
# Model prediction result: Student is unlikely to be placed
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
# use differnt lb encoder model for differnt columns and save it .aslos load differently in function

# %%
# machine learning methodology/steps:
# step 1.problem analysis
# step 2.data collection
# step 3.preprocessing the data
# step 4.visualiztion
# step 5.labeling the data
#    label the data as x and y 
#    x-input,feature,independent
#    y-output,target,dependent
# step 6.splitting the data for training and testing
#     x_train(80%,x)
#     x_test(20%,x)
#     y_train(80%,y)
#     y_test(20%,y)
# step 7.model building
#   chooseing for algorithm
# step 8.model training
#     x_train,y_train
# step 9.model testing
#     x_test-result
# step 10.model evaluation
#      result==y_test
#      more than 75% accuracy
# step 11.model deployment
